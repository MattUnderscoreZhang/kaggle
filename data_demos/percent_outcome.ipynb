# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# read and split data 
train = pd.read_csv("../data/train.csv")
dogs = train[train.AnimalType=="Dog"]
cats = train[train.AnimalType=="Cat"]

# %%
import sys
sys.path.insert(0,"../libs/")
from data_cleaning import percent_outcome
from visualize import bar_percentage

# %%
cat_outcomes = percent_outcome(cats,"OutcomeType")
dog_outcomes = percent_outcome(dogs,"OutcomeType")

# %%
fig_outcome,ax_outcome = bar_percentage(cat_outcomes - dog_outcomes,ylim=(-0.5,0.5))

# %%
pc = percent_outcome( cats[cats.OutcomeType=="Euthanasia"] ,"OutcomeSubtype")
pd = percent_outcome( dogs[dogs.OutcomeType=="Euthanasia"] ,"OutcomeSubtype")

# %%
fig_euth,ax_euth = bar_percentage(pc-pd,ylim=(-0.5,0.6))
